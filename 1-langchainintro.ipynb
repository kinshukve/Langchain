# %%
import langchain
print("LangChain is working!")
print("Version:", langchain.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import langchain
#       2 print("LangChain is working!")
#       3 print("Version:", langchain.__version__)
#
# ModuleNotFoundError: No module named 'langchain'
